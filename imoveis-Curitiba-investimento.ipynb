# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Carregando o arquivo da análise

file = ('curitiba_apartment_real_estate_data.csv')
df = pd.read_csv(file)

# %%
df.head(20)
# Out:
#     usableAreas  totalAreas  suites  bathrooms  bedrooms  parkingSpaces  \
# 0            77        90.0     1.0          2         3            1.0
# 1            53        53.0     NaN          1         3            1.0
# 2           113         NaN     1.0          4         3            2.0
# 3            93       106.0     1.0          2         3            2.0
# 4            66         NaN     1.0          2         3            1.0
# 5            57        70.0     NaN          1         3            1.0
# 6           102         NaN     1.0          3         3            2.0
# 7            88       146.0     1.0          2         3            1.0
# 8            57        70.0     NaN          2         2            1.0
# 9            80       140.0     1.0          2         2            2.0
# 10           38        46.0     NaN          1         2            1.0
# 11          126         NaN     3.0          5         3            2.0
# ...

# %%
df.shape
# Out:
# (18760, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18760 entries, 0 to 18759
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   usableAreas      18760 non-null  int64
#  1   totalAreas       18030 non-null  float64
#  2   suites           17456 non-null  float64
#  3   bathrooms        18760 non-null  int64
#  4   bedrooms         18760 non-null  int64
#  5   parkingSpaces    18097 non-null  float64
#  6   amenities        18760 non-null  object
#  7   description      18730 non-null  object
#  8   title            18633 non-null  object
#  9   zipCode          18760 non-null  int64
#  10  lon              13195 non-null  float64
#  11  lat              13195 non-null  float64
#  12  street           15689 non-null  object
#  13  neighborhood     18760 non-null  object
#  14  poisList         18760 non-null  object
#  15  yearlyIptu       14412 non-null  float64
# ...

# %%
df.describe().round(2)
# Out:
#        usableAreas  totalAreas    suites  bathrooms  bedrooms  parkingSpaces  \
# count     18760.00    18030.00  17456.00   18760.00  18760.00       18097.00
# mean        111.94      204.34      1.23       2.39      2.50           1.58
# std         101.24     2018.78      1.05       1.38      0.88           1.16
# min          10.00        1.00      0.00       1.00      1.00           0.00
# 25%          57.00       69.00      1.00       1.00      2.00           1.00
# 50%          89.00      119.00      1.00       2.00      3.00           1.00
# 75%         139.00      199.00      2.00       3.00      3.00           2.00
# max        5000.00   174932.00      8.00      11.00      8.00          40.00
#
#            zipCode       lon       lat   yearlyIptu  monthlyCondoFee  \
# count     18760.00  13195.00  13195.00     14412.00         15169.00
# mean   80636130.80    -49.28    -25.44      3085.85          4179.38
# ...

# %%
df['Valor_por_m2'] = df['price'] / df['usableAreas']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18760 entries, 0 to 18759
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   usableAreas      18760 non-null  int64
#  1   totalAreas       18030 non-null  float64
#  2   suites           17456 non-null  float64
#  3   bathrooms        18760 non-null  int64
#  4   bedrooms         18760 non-null  int64
#  5   parkingSpaces    18097 non-null  float64
#  6   amenities        18760 non-null  object
#  7   description      18730 non-null  object
#  8   title            18633 non-null  object
#  9   zipCode          18760 non-null  int64
#  10  lon              13195 non-null  float64
#  11  lat              13195 non-null  float64
#  12  street           15689 non-null  object
#  13  neighborhood     18760 non-null  object
#  14  poisList         18760 non-null  object
#  15  yearlyIptu       14412 non-null  float64
# ...

# %%
#Excluir todas linhas de valores nulos seria muito radical pois o dataframe ficaria com metade das linhas, em relação ao original.
df.dropna()
# Out:
#        usableAreas  totalAreas  suites  bathrooms  bedrooms  parkingSpaces  \
# 0               77        90.0     1.0          2         3            1.0
# 3               93       106.0     1.0          2         3            2.0
# 7               88       146.0     1.0          2         3            1.0
# 16              78       130.0     1.0          2         3            2.0
# 23              94       168.0     1.0          2         3            2.0
# ...            ...         ...     ...        ...       ...            ...
# 18728          126       240.0     2.0          2         2            2.0
# 18741          132        10.0     1.0          3         3            1.0
# 18742          132        10.0     1.0          3         3            1.0
# 18751          274       375.0     2.0          3         4            2.0
# 18758          372       700.0     4.0          6         4            5.0
#
#                                                amenities  \
# ...

# %%
#TRATAMENTOS INICIAIS

#totalAreas = excluir
#suites= colocar 0 -> fillna
#parkingSpaces colocar 0 -> fillna
#description e title = excluir
#zipcode trocar o tipo para object -> astype e tentar formatar ela para XXXXX-XXX
#street = "sem endereço" -> fillna
#yearlyIptu = 0 -> fillna
#monthlyCondoFee = 0 -> fillna
#price no formato de milhares XXX.XXX
#Valor_por_m2 no formato XXXXX.XX

#Renomear TODAS as colunas para português

# %%
# criar um grafico pizza, a soma do restante ser representada como outros
df.neighborhood.value_counts(1)[0:10]*100
# Out:
# Água Verde           20.719616
# Centro               15.623667
# Bigorrilho           12.132196
# Batel                 7.771855
# Rebouças              4.371002
# Cabral                3.219616
# Portão                3.027719
# Vila Izabel           2.915778
# Cidade Industrial     2.452026
# Cristo Rei            2.153518
# Name: neighborhood, dtype: float64
